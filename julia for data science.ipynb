# %%
1-1
# Out:
# 0

# %%
import Pkg; Pkg.add("DataFrames")
# Out:
#     Updating registry at `C:\Users\souzavb\.julia\registries\General`
#     Updating git-repo `https://github.com/JuliaRegistries/General.git`
#    Resolving package versions...
#    Installed ZeroMQ_jll ────────────────── v4.3.2+6
#    Installed TableTraits ───────────────── v1.0.0
#    Installed DataValueInterfaces ───────── v1.0.0
#    Installed Crayons ───────────────────── v4.0.4
#    Installed Formatting ────────────────── v0.4.2
#    Installed CategoricalArrays ─────────── v0.9.2
#    Installed IteratorInterfaceExtensions ─ v1.0.0
#    Installed Tables ────────────────────── v1.3.2
#    Installed libsodium_jll ─────────────── v1.0.18+1
#    Installed DataFrames ────────────────── v0.22.5
#    Installed PooledArrays ──────────────── v1.1.0
#    Installed StructTypes ───────────────── v1.2.3
#    Installed InvertedIndices ───────────── v1.0.0
#    Installed PrettyTables ──────────────── v0.11.0
#     Updating `C:\Users\souzavb\.julia\environments\v1.6\Project.toml`
#   [a93c6f00] + DataFrames v0.22.5
#     Updating `C:\Users\souzavb\.julia\environments\v1.6\Manifest.toml`
#   [324d7699] + CategoricalArrays v0.9.2
#   [a8cc5b0e] + Crayons v4.0.4
#   [a93c6f00] + DataFrames v0.22.5
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [59287772] + Formatting v0.4.2
#   [41ab1584] + InvertedIndices v1.0.0
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [2dfb63ee] + PooledArrays v1.1.0
#   [08abe8d2] + PrettyTables v0.11.0
#   [856f2bd8] + StructTypes v1.2.3
#   [3783bdb8] + TableTraits v1.0.0
#   [bd369af6] + Tables v1.3.2
#   [8f1865be] ↑ ZeroMQ_jll v4.3.2+5 ⇒ v4.3.2+6
#   [a9144af2] + libsodium_jll v1.0.18+1
#   [9fa8497b] + Future
# Precompiling project...
#   ✓ Reexport
#   ✓ Requires
#   ✓ DataValueInterfaces
#   ✓ Crayons
#   ✓ Adapt
#   ✓ InvertedIndices
#   ✓ Compat
#   ✓ MacroTools
#   ✓ RecipesBase
#   ✓ OrderedCollections
#   ✓ GR
#   ✓ Formatting
#   ✓ IteratorInterfaceExtensions
#   ✓ FileIO
#   ✓ FixedPointNumbers
#   ✓ Grisu
#   ✓ Ogg_jll
#   ✓ Expat_jll
#   ✓ StaticArrays
#   ✓ Measures
#   ✓ Xorg_xtrans_jll
#   ✓ LaTeXStrings
#   ✓ NaNMath
#   ✓ Graphite2_jll
#   ✓ libsodium_jll
#   ✓ Libuuid_jll
#   ✓ AbstractFFTs
#   ✓ DataAPI
#   ✓ CompilerSupportLibraries_jll
#   ✓ StructTypes
#   ✓ Libiconv_jll
#   ✓ Zstd_jll
#   ✓ ICU_jll
#   ✓ libpng_jll
#   ✓ Xorg_libpthread_stubs_jll
#   ✓ LAME_jll
#   ✓ PCRE_jll
#   ✓ LibVPX_jll
#   ✓ Xorg_libXdmcp_jll
#   ✓ Bzip2_jll
#   ✓ Xorg_libXau_jll
#   ✓ x265_jll
#   ✓ FriBidi_jll
#   ✓ Libgpg_error_jll
#   ✓ Opus_jll
#   ✓ x264_jll
#   ✓ Pixman_jll
#   ✓ LZO_jll
#   ✓ OpenSSL_jll
#   ✓ Libffi_jll
#   ✓ libfdk_aac_jll
#   ✓ JpegTurbo_jll
#   ✓ Libmount_jll
#   ✓ OffsetArrays
#   ✓ ChainRulesCore
#   ✓ Media
#   ✓ TableTraits
#   ✓ DataStructures
#   ✓ MappedArrays
#   ✓ Showoff
#   ✓ libvorbis_jll
#   ✓ ColorTypes
#   ✓ Contour
#   ✓ Missings
#   ✓ ZeroMQ_jll
#   ✓ PooledArrays
#   ✓ OpenSpecFun_jll
#   ✓ XML2_jll
#   ✓ FreeType2_jll
#   ✓ Libgcrypt_jll
#   ✓ PaddedViews
#   ✓ Libtiff_jll
#   ✓ Juno
#   ✓ SortingAlgorithms
#   ✓ Tables
#   ✓ GeometryTypes
#   ✓ Colors
#   ✓ CategoricalArrays
#   ? ZMQ
#   ✓ Gettext_jll
#   ✓ Fontconfig_jll
#   ✓ SpecialFunctions
#   ✓ libass_jll
#   ✓ MosaicViews
#   ✓ XSLT_jll
#   ✓ LittleCMS_jll
#   ✓ StatsBase
#   ✓ PrettyTables
#   ✓ Graphics
#   ✓ Glib_jll
#   ✓ PlotUtils
#   ✓ Xorg_libxcb_jll
#   ✓ OpenJpeg_jll
#   ✓ FFMPEG_jll
#   ✓ ColorVectorSpace
#   ✓ ImageCore
#   ✓ PlotThemes
#   ✓ RecipesPipeline
#   ✓ Xorg_libX11_jll
#   ✓ FFMPEG
#   ✗ ImageMagick
#   ✓ QuartzImageIO
#   ✓ Xorg_libXrender_jll
#   ✓ Xorg_libXext_jll
#   ✓ DataFrames
#   ✓ Cairo_jll
#   ✓ HarfBuzz_jll
#   ✓ Poppler_jll
#   ✓ Pango_jll
#   ✓ TikzPictures
#   ✓ Cairo
#   ✓ Luxor
#   ✓ Plots
# 111 dependencies successfully precompiled in 252 seconds (12 already precompiled)
# 1 dependency failed but may be precompilable after restarting julia
# 1 dependency errored

# %%
import Pkg; Pkg.add("Gadfly")
# Out:
#    Resolving package versions...
#    Installed Rmath ─────────────── v0.6.1
#    Installed AxisAlgorithms ────── v1.0.0
#    Installed KernelDensity ─────── v0.6.2
#    Installed PDMats ────────────── v0.10.1
#    Installed Distances ─────────── v0.10.2
#    Installed DocStringExtensions ─ v0.8.3
#    Installed Rmath_jll ─────────── v0.2.2+1
#    Installed FFTW_jll ──────────── v3.3.9+7
#    Installed Hexagons ──────────── v0.2.0
#    Installed SpecialFunctions ──── v0.10.3
#    Installed CoupledFields ─────── v0.2.0
#    Installed FFTW ──────────────── v1.3.1
#    Installed FillArrays ────────── v0.9.7
#    Installed QuadGK ────────────── v2.4.1
#    Installed Gadfly ────────────── v1.3.1
#    Installed Distributions ─────── v0.23.11
#    Installed WoodburyMatrices ──── v0.5.3
#    Installed Ratios ────────────── v0.4.0
#    Installed IntelOpenMP_jll ───── v2018.0.3+2
#    Installed IndirectArrays ────── v0.5.1
#    Installed StatsFuns ─────────── v0.9.6
#    Installed IterTools ─────────── v1.3.0
#    Installed Compose ───────────── v0.9.2
#    Installed CategoricalArrays ─── v0.8.3
#    Installed Interpolations ────── v0.13.1
#    Installed Loess ─────────────── v0.5.3
#    Installed MKL_jll ───────────── v2020.2.254+0
#     Updating `C:\Users\souzavb\.julia\environments\v1.6\Project.toml`
#   [c91e804a] + Gadfly v1.3.1
#     Updating `C:\Users\souzavb\.julia\environments\v1.6\Manifest.toml`
#   [13072b0f] + AxisAlgorithms v1.0.0
#   [324d7699] ↓ CategoricalArrays v0.9.2 ⇒ v0.8.3
#   [d360d2e6] - ChainRulesCore v0.9.27
#   [a81c6b42] + Compose v0.9.2
#   [7ad07ef1] + CoupledFields v0.2.0
#   [b4f34e82] + Distances v0.10.2
#   [31c24e10] + Distributions v0.23.11
#   [ffbed154] + DocStringExtensions v0.8.3
#   [7a1cc6ca] + FFTW v1.3.1
#   [1a297f60] + FillArrays v0.9.7
#   [c91e804a] + Gadfly v1.3.1
#   [a1b4810d] + Hexagons v0.2.0
#   [9b13fd28] + IndirectArrays v0.5.1
#   [a98d9a8b] + Interpolations v0.13.1
#   [c8e1da08] + IterTools v1.3.0
#   [5ab0869b] + KernelDensity v0.6.2
#   [4345ca2d] + Loess v0.5.3
#   [90014a1f] + PDMats v0.10.1
#   [1fd47b50] + QuadGK v2.4.1
#   [c84ed2f1] + Ratios v0.4.0
#   [79098fc4] + Rmath v0.6.1
#   [276daf66] ↓ SpecialFunctions v1.2.1 ⇒ v0.10.3
#   [4c63d2b9] + StatsFuns v0.9.6
#   [efce3f68] + WoodburyMatrices v0.5.3
#   [f5851436] + FFTW_jll v3.3.9+7
#   [1d5cc7b8] + IntelOpenMP_jll v2018.0.3+2
#   [856f044c] + MKL_jll v2020.2.254+0
#   [f50d1b31] + Rmath_jll v0.2.2+1
#   [4607b0f0] + SuiteSparse
#     Building FFTW → `C:\Users\souzavb\.julia\scratchspaces\44cfe95a-1eb2-52ea-b672-e2afdf69b78f\c31e446bf3b12aad2ec8fc500fe19528c148d811\build.log`
# Precompiling project...
#   ✓ Hexagons
#   ✓ PDMats
#   ✓ IterTools
#   ✓ Rmath_jll
#   ✓ FillArrays
#   ✓ DocStringExtensions
#   ✓ Distances
#   ✓ IndirectArrays
#   ✓ Ratios
#   ✓ WoodburyMatrices
#   ✓ QuadGK
#   ✓ FFTW_jll
#   ✓ IntelOpenMP_jll
#   ✓ SpecialFunctions
#   ✓ CategoricalArrays
#   ✓ CoupledFields
#   ✓ Rmath
#   ✓ Loess
#   ✓ AxisAlgorithms
#   ✓ Compose
#   ✓ MKL_jll
#   ? DataFrames
#   ✓ ColorVectorSpace
#   ✓ StatsFuns
#   ✓ FFTW
#   ✓ Interpolations
#   ✓ QuartzImageIO
#   ✓ Luxor
#   ✓ Distributions
#   ✓ KernelDensity
#   ? Gadfly
# 29 dependencies successfully precompiled in 43 seconds (117 already precompiled, 1 skipped during auto due to previous errors)
# 2 dependencies failed but may be precompilable after restarting julia

# %%
using DataFrames, Gadfly
p = plot(x=randn(2000), Geom.histogram(bincount=100))
# Out:
# ┌ Info: Precompiling Gadfly [c91e804a-d5a3-530f-b6f0-dfbca275c004]
# └ @ Base loading.jl:1313
# ┌ Warning: Module CategoricalArrays with build ID 118878769811503 is missing from the cache.
# │ This may mean CategoricalArrays [324d7699-5711-5eae-9e2f-1d82baa6b597] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1004
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Gadfly [c91e804a-d5a3-530f-b6f0-dfbca275c004].
# └ @ Base loading.jl:1021
# Plot(...)

# %%
Pkg.status()
# Out:
#       Status `C:\Users\souzavb\.julia\environments\v1.6\Project.toml`
#   [a93c6f00] DataFrames v0.22.5
#   [c91e804a] Gadfly v1.3.1
#   [7073ff75] IJulia v1.23.1
#   [b51cafcc] JuliaIntroBR v0.1.0 `https://github.com/JuliaIntro/JuliaIntroBR.jl#master`
#   [a7f2b756] ThinkJulia v0.0.0 `https://github.com/BenLauwens/ThinkJulia.jl#master`

# %%
Pkg.installed()
# Out:
# ┌ Warning: Pkg.installed() is deprecated
# └ @ Pkg C:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.6\Pkg\src\Pkg.jl:565
# Dict{String, VersionNumber} with 5 entries:
#   "ThinkJulia"   => v"0.0.0"
#   "IJulia"       => v"1.23.1"
#   "DataFrames"   => v"0.22.5"
#   "JuliaIntroBR" => v"0.1.0"
#   "Gadfly"       => v"1.3.1"

# %%
f(x::Float64,y::Float64) = x+y
# Out:
# f (generic function with 1 method)

# %%
f(2,4)
# Out:
# MethodError: no method matching f(::Int64, ::Int64)
#
# Stacktrace:
#  [1] top-level scope
#    @ In[13]:1
#  [2] eval
#    @ .\boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1090

# %%
f(2.0,4.0)
# Out:
# 6.0

# %%
g(x, y) = x*y
# Out:
# g (generic function with 1 method)

# %%
g(2, 5)
# Out:
# 10

# %%
g(2.0, 5.0)
# Out:
# 10.0

# %%
g("a", "b")
# Out:
# "ab"

# %%
df = DataFrame(Name = ["Ana","Maria","Julia","Gabriela","Amanda"],
     Count = [14.1,12.3,16.2,13.4,11.9],
     OS = ["U","W","W","W","U"])
# Out:
# 5×3 DataFrame
#  Row │ Name      Count    OS
#      │ String    Float64  String
# ─────┼───────────────────────────
#    1 │ Ana          14.1  U
#    2 │ Maria        12.3  W
#    3 │ Julia        16.2  W
#    4 │ Gabriela     13.4  W
#    5 │ Amanda       11.9  U

# %%
size(df)
# Out:
# (5, 3)

# %%
describe(df[!,"Count"])
# Out:
# Summary Stats:
# Length:         5
# Missing Count:  0
# Mean:           13.580000
# Minimum:        11.900000
# 1st Quartile:   12.300000
# Median:         13.400000
# 3rd Quartile:   14.100000
# Maximum:        16.200000
# Type:           Float64

# %%
Pkg.add("RDatasets")
# Out:
#    Resolving package versions...
#    Installed SentinelArrays ───── v1.2.16
#    Installed CodecZlib ────────── v0.7.0
#    Installed ExprTools ────────── v0.1.3
#    Installed Mocking ──────────── v0.7.1
#    Installed EzXML ────────────── v1.1.0
#    Installed TranscodingStreams ─ v0.9.5
#    Installed RData ────────────── v0.7.3
#    Installed TimeZones ────────── v1.5.3
#    Installed CSV ──────────────── v0.8.3
#    Installed RDatasets ────────── v0.7.4
#     Updating `C:\Users\souzavb\.julia\environments\v1.6\Project.toml`
#   [ce6b1742] + RDatasets v0.7.4
#     Updating `C:\Users\souzavb\.julia\environments\v1.6\Manifest.toml`
#   [336ed68f] + CSV v0.8.3
#   [944b1d66] + CodecZlib v0.7.0
#   [e2ba6199] + ExprTools v0.1.3
#   [8f5d6c58] + EzXML v1.1.0
#   [78c3b35d] + Mocking v0.7.1
#   [df47a6cb] + RData v0.7.3
#   [ce6b1742] + RDatasets v0.7.4
#   [91c51154] + SentinelArrays v1.2.16
#   [f269a46b] + TimeZones v1.5.3
#   [3bb67fe8] + TranscodingStreams v0.9.5
#     Building TimeZones → `C:\Users\souzavb\.julia\scratchspaces\44cfe95a-1eb2-52ea-b672-e2afdf69b78f\4ba8a9579a243400db412b50300cd61d7447e583\build.log`
# Precompiling project...
#   ✓ TranscodingStreams
#   ✓ SentinelArrays
#   ✓ CodecZlib
#   ? Gadfly
#   ? RData
#   ✓ CSV
#   ? RDatasets
# 4 dependencies successfully precompiled in 20 seconds (151 already precompiled, 2 skipped during auto due to previous errors)
# 3 dependencies failed but may be precompilable after restarting julia

# %%
Pkg.build("RDatasets")
# Out:
#     Building TimeZones → `C:\Users\souzavb\.julia\scratchspaces\44cfe95a-1eb2-52ea-b672-e2afdf69b78f\4ba8a9579a243400db412b50300cd61d7447e583\build.log`
# Precompiling project...
#   ? RData
#   ? Gadfly
#   ? RDatasets

# %%
using RDatasets
RDatasets.packages()
# Out:
# ┌ Info: Precompiling RDatasets [ce6b1742-4840-55fa-b093-852dadbb1d8b]
# └ @ Base loading.jl:1313
# ┌ Warning: Module DataFrames with build ID 118909749937296 is missing from the cache.
# │ This may mean DataFrames [a93c6f00-e57d-5684-b7b6-d8193f3e46c0] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1004
# ┌ Warning: Module DataFrames with build ID 118909749937296 is missing from the cache.
# │ This may mean DataFrames [a93c6f00-e57d-5684-b7b6-d8193f3e46c0] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1004
# ┌ Info: Skipping precompilation since __precompile__(false). Importing RDatasets [ce6b1742-4840-55fa-b093-852dadbb1d8b].
# └ @ Base loading.jl:1021
# ┌ Info: Precompiling RData [df47a6cb-8c03-5eed-afd8-b6050d6c41da]
# └ @ Base loading.jl:1313
# ┌ Warning: Module DataFrames with build ID 118909749937296 is missing from the cache.
# │ This may mean DataFrames [a93c6f00-e57d-5684-b7b6-d8193f3e46c0] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1004
# ┌ Info: Skipping precompilation since __precompile__(false). Importing RData [df47a6cb-8c03-5eed-afd8-b6050d6c41da].
# └ @ Base loading.jl:1021
# 34×2 DataFrame
#  Row │ Package       Title
#      │ String        String
# ─────┼─────────────────────────────────────────────────
#    1 │ COUNT         Functions, data and code for cou…
#    2 │ Ecdat         Data sets for econometrics
#    3 │ HSAUR         A Handbook of Statistical Analys…
#    4 │ HistData      Data sets from the history of st…
#    5 │ ISLR          Data for An Introduction to Stat…
#    6 │ KMsurv        Data sets from Klein and Moeschb…
#    7 │ MASS          Support Functions and Datasets f…
#    8 │ SASmixed      Data sets from \\
#    9 │ Zelig         Everyone's Statistical Software
#   10 │ adehabitatLT  Analysis of Animal Movements
#   11 │ boot          Bootstrap Functions (Originally …
#   ⋮  │      ⋮                        ⋮
#   25 │ pscl          Political Science Computational …
#   26 │ psych         Procedures for Psychological, Ps…
#   27 │ quantreg      Quantile Regression
#   28 │ reshape2      Flexibly Reshape Data: A Reboot …
#   29 │ robustbase    Basic Robust Statistics
#   30 │ rpart         Recursive Partitioning and Regre…
#   31 │ sandwich      Robust Covariance Matrix Estimat…
#   32 │ sem           Structural Equation Models
#   33 │ survival      Survival Analysis
#   34 │ vcd           Visualizing Categorical Data
#                                         13 rows omitted

# %%
iris_dataset = dataset("datasets", "iris")
# Out:
# 150×5 DataFrame
#  Row │ SepalLength  SepalWidth  PetalLength  PetalWidth  Species
#      │ Float64      Float64     Float64      Float64     Cat…
# ─────┼─────────────────────────────────────────────────────────────
#    1 │         5.1         3.5          1.4         0.2  setosa
#    2 │         4.9         3.0          1.4         0.2  setosa
#    3 │         4.7         3.2          1.3         0.2  setosa
#    4 │         4.6         3.1          1.5         0.2  setosa
#    5 │         5.0         3.6          1.4         0.2  setosa
#    6 │         5.4         3.9          1.7         0.4  setosa
#    7 │         4.6         3.4          1.4         0.3  setosa
#    8 │         5.0         3.4          1.5         0.2  setosa
#    9 │         4.4         2.9          1.4         0.2  setosa
#   10 │         4.9         3.1          1.5         0.1  setosa
#   11 │         5.4         3.7          1.5         0.2  setosa
#   ⋮  │      ⋮           ⋮            ⋮           ⋮           ⋮
#  141 │         6.7         3.1          5.6         2.4  virginica
#  142 │         6.9         3.1          5.1         2.3  virginica
#  143 │         5.8         2.7          5.1         1.9  virginica
#  144 │         6.8         3.2          5.9         2.3  virginica
#  145 │         6.7         3.3          5.7         2.5  virginica
#  146 │         6.7         3.0          5.2         2.3  virginica
#  147 │         6.3         2.5          5.0         1.9  virginica
#  148 │         6.5         3.0          5.2         2.0  virginica
#  149 │         6.2         3.4          5.4         2.3  virginica
#  150 │         5.9         3.0          5.1         1.8  virginica
#                                                    129 rows omitted

# %%
describe(iris_dataset)
# Out:
# 5×7 DataFrame
#  Row │ variable     mean     min     median  max        nmissing  eltype       ⋯
#      │ Symbol       Union…   Any     Union…  Any        Int64     DataType     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ SepalLength  5.84333  4.3     5.8     7.9               0  Float64      ⋯
#    2 │ SepalWidth   3.05733  2.0     3.0     4.4               0  Float64
#    3 │ PetalLength  3.758    1.0     4.35    6.9               0  Float64
#    4 │ PetalWidth   1.19933  0.1     1.3     2.5               0  Float64
#    5 │ Species               setosa          virginica         0  CategoricalV ⋯
#                                                                 1 column omitted

# %%
sort!(iris_dataset)
# Out:
# 150×5 DataFrame
#  Row │ SepalLength  SepalWidth  PetalLength  PetalWidth  Species
#      │ Float64      Float64     Float64      Float64     Cat…
# ─────┼──────────────────────────────────────────────────────────────
#    1 │         4.3         3.0          1.1         0.1  setosa
#    2 │         4.4         2.9          1.4         0.2  setosa
#    3 │         4.4         3.0          1.3         0.2  setosa
#    4 │         4.4         3.2          1.3         0.2  setosa
#    5 │         4.5         2.3          1.3         0.3  setosa
#    6 │         4.6         3.1          1.5         0.2  setosa
#    7 │         4.6         3.2          1.4         0.2  setosa
#    8 │         4.6         3.4          1.4         0.3  setosa
#    9 │         4.6         3.6          1.0         0.2  setosa
#   10 │         4.7         3.2          1.3         0.2  setosa
#   11 │         4.7         3.2          1.6         0.2  setosa
#   ⋮  │      ⋮           ⋮            ⋮           ⋮           ⋮
#  141 │         7.2         3.2          6.0         1.8  virginica
#  142 │         7.2         3.6          6.1         2.5  virginica
#  143 │         7.3         2.9          6.3         1.8  virginica
#  144 │         7.4         2.8          6.1         1.9  virginica
#  145 │         7.6         3.0          6.6         2.1  virginica
#  146 │         7.7         2.6          6.9         2.3  virginica
#  147 │         7.7         2.8          6.7         2.0  virginica
#  148 │         7.7         3.0          6.1         2.3  virginica
#  149 │         7.7         3.8          6.7         2.2  virginica
#  150 │         7.9         3.8          6.4         2.0  virginica
#                                                     129 rows omitted

# %%
plot(iris_dataset, x="SepalLength", y="SepalWidth",color="Species")
# Out:
# Plot(...)

# %%
plot(iris_dataset, x="PetalLength", y="PetalWidth",color="Species")
# Out:
# Plot(...)

# %%
plot(iris_dataset, x="PetalLength", Geom.density, color="Species")
# Out:
# Plot(...)

# %%
plot(iris_dataset, x="SepalLength", Geom.density, color="Species")
# Out:
# Plot(...)
